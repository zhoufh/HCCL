# %%
import scanpy as sc
adata = sc.read_h5ad('result/151507_params_1_1.5_0.5_0.1_final.h5ad')
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (5,5)
sc.pp.neighbors(adata, use_rep='emb', n_neighbors=30)
sc.tl.umap(adata)
sc.tl.paga(adata, groups='original_clusters')
sc.pl.paga_compare(adata, legend_fontsize=10, legend_fontoutline=1, legend_loc = 'lower center',size=45)
# Out:
# D:\SoftWare\anaconda\envs\hcgcl\Lib\site-packages\anndata\utils.py:434: FutureWarning: Importing read_csv from `anndata` is deprecated. Import anndata.io.read_csv instead.
#   warnings.warn(msg, FutureWarning)
# D:\SoftWare\anaconda\envs\hcgcl\Lib\site-packages\anndata\utils.py:434: FutureWarning: Importing read_text from `anndata` is deprecated. Import anndata.io.read_text instead.
#   warnings.warn(msg, FutureWarning)
# D:\SoftWare\anaconda\envs\hcgcl\Lib\site-packages\anndata\utils.py:434: FutureWarning: Importing read_excel from `anndata` is deprecated. Import anndata.io.read_excel instead.
#   warnings.warn(msg, FutureWarning)
# D:\SoftWare\anaconda\envs\hcgcl\Lib\site-packages\anndata\utils.py:434: FutureWarning: Importing read_mtx from `anndata` is deprecated. Import anndata.io.read_mtx instead.
#   warnings.warn(msg, FutureWarning)
# ...
